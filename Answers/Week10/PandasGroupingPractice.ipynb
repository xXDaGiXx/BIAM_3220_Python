# %%
import pandas as pd

# %%
wine = pd.read_csv("winemag-data-130k-v2.csv", index_col = 0)

# %%
wine.head(2)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
# 1      87   15.0              Douro      NaN      NaN     Roger Voss
#
#   taster_twitter_handle                                          title  \
# 0          @kerinokeefe              Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos

# %%
wine.groupby(['points']).points.count()
# Out:
# points
# 80       397
# 81       692
# 82      1836
# 83      3025
# 84      6480
# 85      9530
# 86     12600
# 87     16933
# 88     17207
# 89     12226
# 90     15410
# 91     11359
# 92      9613
# 93      6489
# 94      3758
# 95      1535
# 96       523
# 97       229
# 98        77
# 99        33
# 100       19
# Name: points, dtype: int64

# %%
wine.groupby(['points']).points.min()
# Out:
# points
# 80      80
# 81      81
# 82      82
# 83      83
# 84      84
# 85      85
# 86      86
# 87      87
# 88      88
# 89      89
# 90      90
# 91      91
# 92      92
# 93      93
# 94      94
# 95      95
# 96      96
# 97      97
# 98      98
# 99      99
# 100    100
# Name: points, dtype: int64

# %%
wine.groupby(['points']).points.max()
# Out:
# points
# 80      80
# 81      81
# 82      82
# 83      83
# 84      84
# 85      85
# 86      86
# 87      87
# 88      88
# 89      89
# 90      90
# 91      91
# 92      92
# 93      93
# 94      94
# 95      95
# 96      96
# 97      97
# 98      98
# 99      99
# 100    100
# Name: points, dtype: int64

# %%
wine.groupby(['country']).points.max()
# Out:
# country
# Argentina                  97
# Armenia                    88
# Australia                 100
# Austria                    98
# Bosnia and Herzegovina     88
# Brazil                     89
# Bulgaria                   91
# Canada                     94
# Chile                      95
# China                      89
# Croatia                    91
# Cyprus                     89
# Czech Republic             89
# Egypt                      84
# England                    95
# France                    100
# Georgia                    92
# Germany                    98
# Greece                     93
# Hungary                    97
# India                      93
# Israel                     94
# Italy                     100
# Lebanon                    91
# Luxembourg                 90
# Macedonia                  89
# Mexico                     92
# Moldova                    91
# Morocco                    93
# New Zealand                95
# ...

# %%
round(wine.groupby(['country']).price.agg(['count','mean','std']),2)
# Out:
#                         count   mean    std
# country
# Argentina                3756  24.51  23.43
# Armenia                     2  14.50   0.71
# Australia                2294  35.44  49.05
# Austria                  2799  30.76  27.22
# Bosnia and Herzegovina      2  12.50   0.71
# Brazil                     47  23.77  11.05
# Bulgaria                  141  14.65   9.51
# Canada                    254  35.71  19.66
# Chile                    4416  20.79  21.93
# China                       1  18.00    NaN
# Croatia                    71  25.45  12.99
# Cyprus                     11  16.27   2.83
# Czech Republic             12  24.25  12.05
# Egypt                       0    NaN    NaN
# England                    69  51.68  14.86
# France                  17776  41.14  73.77
# Georgia                    84  19.32   7.64
# Germany                  2120  42.26  62.86
# Greece                    461  22.36  10.61
# Hungary                   145  40.65  69.45
# ...

# %%
wine.where(wine['country']=='US').groupby('country').price.describe()
# Out:
#            count       mean        std  min   25%   50%   75%     max
# country
# US       54265.0  36.573464  27.088857  4.0  20.0  30.0  45.0  2013.0

# %%
wine.groupby(['country']).points.describe().sort_values(by='mean',ascending=False)
# Out:
#                           count       mean       std   min    25%   50%  \
# country
# England                    74.0  91.581081  1.843216  89.0  90.00  91.0
# India                       9.0  90.222222  1.715938  87.0  90.00  90.0
# Austria                  3345.0  90.101345  2.499799  82.0  88.00  90.0
# Germany                  2165.0  89.851732  2.469351  81.0  88.00  90.0
# Canada                    257.0  89.369650  2.384752  82.0  88.00  90.0
# Hungary                   146.0  89.191781  2.686659  81.0  88.00  89.0
# China                       1.0  89.000000       NaN  89.0  89.00  89.0
# France                  22093.0  88.845109  3.044423  80.0  87.00  89.0
# Luxembourg                  6.0  88.666667  0.816497  88.0  88.00  88.5
# Australia                2329.0  88.580507  2.989900  80.0  87.00  89.0
# Switzerland                 7.0  88.571429  2.507133  83.0  89.00  89.0
# Morocco                    28.0  88.571429  1.687175  85.0  88.00  88.5
# ...
