# %% [markdown]
# # BAIM 3220: Final Exam Part 2
# ## Learning Objectives
# 1. Analyze data using python
# 2. Filter and group data
# 3. Join DataFrames
# 4. Create calculated columns

# %% [markdown]
# # Quiz Directions
# >- Use this notebook to write python code to answer questions given in the Canvas `Final: Part 2`
# >- Enter your answers to the questions in Canvas based on your python code
# >- Note: you may want to copy and paste the text from the Canvas Questions into markdown cells as you work
#
# ## General Grading Guidelines
# >- 1/3 points for reasonable attempt to solve the problem with python
# >>- Show your work for each question under the appropriate header in this notebook.
# >>>- You can add/remove code cells as needed but keep all work per question under the appropriate header
# >>- You can't put anything down in a code cell and receive credit
# >>- A reasonable attempt can include a variety of the following:
# >>>- Using python code discussed in class to solve the given problem
# >>>- Using python code found from an external source that seems reasonable to solve the given problem
# >>>- The python code is clearly on the right track to solving the problem but the code may contain minor errors
# >- 2/3 points for correct answer entered on Canvas
# >>- Show your work in the notebook but make sure to input the correct answer on Canvas

# %% [markdown]
# ## Read in a Combined and Cleaned BLS Dataset into a DataFrame
# >- If you do not have a combined and cleaned dataset you will need to do that prior to answering the analysis questions
# >- You will need to combine and clean the same BLS datasets we worked with earlier in the class
# >>- BLS2008.xlsx
# >>- BLS2009.xlsx
# >>- BLS2010.xlsx
# >>- BLS2011.xlsx

# %%
import pandas as pd, os

# %%
bls08 = pd.read_excel('BLS2008.xlsx')
bls09 = pd.read_excel('BLS2009.xlsx')
bls10 = pd.read_excel('BLS2010.xlsx')
bls11 = pd.read_excel('BLS2011.xlsx')
oes = pd.read_excel('oesDetail.xlsx')
bls4yr = pd.read_excel('bls4yr_copy.xlsx')

# %%
bls4yr.head()
# Out:
#    year occ_code                        occ_title   group    tot_emp  \
# 0  2008  00-0000                  all occupations   total  135185230
# 1  2008  11-0000           management occupations   major    6152650
# 2  2008  11-1011                 chief executives  detail     301930
# 3  2008  11-1021  general and operations managers  detail    1697690
# 4  2008  11-1031                      legislators  detail      64650
#
#    emp_prse  h_mean    a_mean  mean_prse  h_pct10  ...  h_median  h_pct75  \
# 0       0.1   20.32   42270.0        0.1     8.02  ...     15.57    24.78
# 1       0.2   48.23  100310.0        0.2    20.40  ...     42.15    60.74
# 2       0.7   77.13  160440.0        0.5    33.02  ...     76.23      NaN
# 3       0.3   51.91  107970.0        0.2    21.83  ...     44.02    65.87
# 4       1.2     NaN   37980.0        1.1      NaN  ...       NaN      NaN
#
#    h_pct90  a_pct10   a_pct25  a_median   a_pct75  a_pct90  annual  hourly
# ...

# %% [markdown]
# # Show your work to answer Canvas questions
# >- Use the next cells to answer questions given on the Canvas quiz

# %% [markdown]
# # Question 1
# ## Show your work to answer question 1 from Canvas here
# #### There were several changes made to the detailed occupation categories starting in 2010. In 2009, the OCC code for Database administrators was 15-1061. What did the code change to in 2010? Type (or copy and paste) the Occupation Code exactly as it shows in the spreadsheet. Your answer must have the form ##-####.

# %%
bls09.loc[bls09['occ_title']=='Database administrators']
# Out:
#    occ_code                occ_title group  tot_emp  emp_prse h_mean a_mean  \
# 74  15-1061  Database administrators   NaN   108080       1.0  35.72  74290
#
#     mean_prse h_pct10 h_pct25 h_median h_pct75 h_pct90 a_pct10 a_pct25  \
# 74        0.7   19.61   25.71     34.4   44.83    54.9   40780   53470
#
#    a_median a_pct75 a_pct90 annual hourly
# 74    71550   93260  114200    NaN    NaN

# %%
bls10.loc[bls10['OCC_TITLE'].str.contains('Database')]
# Out:
#    OCC_CODE                OCC_TITLE GROUP  TOT_EMP  EMP_PRSE H_MEAN A_MEAN  \
# 72  15-1141  Database Administrators   NaN   104080       1.0  36.41  75730
#
#     MEAN_PRSE H_PCT10 H_PCT25 H_MEDIAN H_PCT75 H_PCT90 A_PCT10 A_PCT25  \
# 72        0.7   19.99   26.08    35.33   45.76   55.61   41570   54250
#
#    A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# 72    73490   95170  115660    NaN    NaN

# %%
bls10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 819 entries, 0 to 818
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   OCC_CODE   819 non-null    object
#  1   OCC_TITLE  819 non-null    object
#  2   GROUP      23 non-null     object
#  3   TOT_EMP    819 non-null    int64
#  4   EMP_PRSE   819 non-null    float64
#  5   H_MEAN     819 non-null    object
#  6   A_MEAN     819 non-null    object
#  7   MEAN_PRSE  819 non-null    float64
#  8   H_PCT10    819 non-null    object
#  9   H_PCT25    819 non-null    object
#  10  H_MEDIAN   819 non-null    object
#  11  H_PCT75    819 non-null    object
#  12  H_PCT90    819 non-null    object
#  13  A_PCT10    819 non-null    object
#  14  A_PCT25    819 non-null    object
#  15  A_MEDIAN   819 non-null    object
#  16  A_PCT75    819 non-null    object
#  17  A_PCT90    819 non-null    object
#  18  ANNUAL     57 non-null     object
# ...

# %% [markdown]
# # Question 2
# ## Show your work to answer question 2 from Canvas here
# #### Which year saw the lowest total number employed in Management occupations?

# %%
# bls4yr.loc[bls4yr['occ_title'].str.contains('management occupations')]
# 11-0000
bls4yr.loc[bls4yr['occ_code']=='11-0000'].groupby(['year','occ_title']).tot_emp.sum().sort_values()
# Out:
# year  occ_title
# 2010  management occupations    6022860
# 2009  management occupations    6116380
# 2008  management occupations    6152650
# 2011  management occupations    6183820
# Name: tot_emp, dtype: int64

# %% [markdown]
# # Question 3
# ## Show your work to answer question 3 from Canvas here
# #### In the category Personal care and service occupations, how many were employed at the lowest point for the years 2008 to 2011? Enter your response without commas.

# %%
# bls4yr[['occ_code','occ_title']].loc[bls4yr['occ_title'].str.contains('personal care and service occupations')]
#39-0000
bls4yr.loc[bls4yr['occ_code']=='39-0000'].sort_values(by='tot_emp')
# Out:
#       year occ_code                              occ_title  group  tot_emp  \
# 2064  2010  39-0000  personal care and service occupations  major  3425220
# 419   2008  39-0000  personal care and service occupations  major  3437520
# 1242  2009  39-0000  personal care and service occupations  major  3461910
# 2883  2011  39-0000  personal care and service occupations  major  3619250
#
#       emp_prse  h_mean   a_mean  mean_prse  h_pct10  ...  h_median  h_pct75  \
# 2064       0.4   11.82  24590.0        0.3     7.73  ...      9.92    13.07
# 419        0.4   11.59  24120.0        0.3     7.19  ...      9.82    13.09
# 1242       0.5   11.87  24680.0        0.4     7.50  ...      9.99    13.33
# 2883       0.4   11.84  24620.0        0.2     7.91  ...      9.96    13.08
#
#       h_pct90  a_pct10  a_pct25  a_median  a_pct75  a_pct90  annual  hourly
# 2064    18.43  16080.0  17700.0   20640.0  27180.0  38330.0     NaN     NaN
# ...

# %% [markdown]
# # Question 4
# ## Show your work to answer question 4 from Canvas here
# #### What was the lowest mean annual wage for Protective service occupations between 2008 and 2011? Enter your response without commas or dollar signs.

# %%
#39-0000
bls4yr[['year','occ_code','occ_title','a_mean']].loc[bls4yr['occ_code']=='39-0000'].sort_values(by='a_mean')
# Out:
#       year occ_code                              occ_title   a_mean
# 419   2008  39-0000  personal care and service occupations  24120.0
# 2064  2010  39-0000  personal care and service occupations  24590.0
# 2883  2011  39-0000  personal care and service occupations  24620.0
# 1242  2009  39-0000  personal care and service occupations  24680.0

# %% [markdown]
# # Question 5
# ## Show your work to answer question 5 from Canvas here.
# #### How did the mean annual wage for Building and grounds cleaning and maintenance occupations rank out of all 22 major occupations in 2009? Rank from highest to lowest where rank = 1 means the occupations with the highest mean annual wage.

# %%
bls4yr[['year','group','occ_code','occ_title','a_mean']].loc[(bls4yr['year']==2009) & (bls4yr['group']=='major')]\
.sort_values(by='a_mean',ascending=False).reset_index(drop=True)
# Out:
#     year  group occ_code                                          occ_title  \
# 0   2009  major  11-0000                             management occupations
# 1   2009  major  23-0000                                  legal occupations
# 2   2009  major  15-0000              computer and mathematical occupations
# 3   2009  major  17-0000           architecture and engineering occupations
# 4   2009  major  29-0000  healthcare practitioners and technical occupat...
# 5   2009  major  13-0000      business and financial operations occupations
# 6   2009  major  19-0000     life, physical, and social science occupations
# 7   2009  major  27-0000  arts, design, entertainment, sports, and media...
# 8   2009  major  25-0000       education, training, and library occupations
# 9   2009  major  47-0000            construction and extraction occupations
# 10  2009  major  21-0000          community and social services occupations
# ...

# %% [markdown]
# # Question 6
# ## Show your work to answer question 6 from Canvas here
# #### For jobs that had total employment between 500,000 and 1,000,000 in 2011, which job category had a percentage growth in employment from 2010 to 2011 equal to 0.38%? Type (or copy and paste) the Occupation Code exactly as it shows in the spreadsheet. Your answer must have the form ##-####.

# %%
totEmp10 = bls4yr.loc[bls4yr['year']==2010].groupby('occ_code').tot_emp.sum()
totEmp10
# Out:
# occ_code
# 00-0000    127097160
# 11-0000      6022860
# 11-1011       273500
# 11-1021      1708080
# 11-1031        65710
#              ...
# 53-7073        12960
# 53-7081       126360
# 53-7111         3080
# 53-7121        10390
# 53-7199        28040
# Name: tot_emp, Length: 819, dtype: int64

# %%
totEmp11 = bls4yr.loc[bls4yr['year']==2011].groupby('occ_code').tot_emp.sum()
totEmp11
# Out:
# occ_code
# 00-0000    128278550
# 11-0000      6183820
# 11-1011       267370
# 11-1021      1805030
# 11-1031        62180
#              ...
# 53-7073        13190
# 53-7081       123160
# 53-7111         3080
# 53-7121        10960
# 53-7199        28370
# Name: tot_emp, Length: 819, dtype: int64

# %%
totEmp1 = totEmp10+totEmp11
totEmp1
# Out:
# occ_code
# 00-0000    255375710
# 11-0000     12206680
# 11-1011       540870
# 11-1021      3513110
# 11-1031       127890
#              ...
# 53-7073        26150
# 53-7081       249520
# 53-7111         6160
# 53-7121        21350
# 53-7199        56410
# Name: tot_emp, Length: 819, dtype: int64

# %%
totEmp1['45-0000']
# Out:
# 817630

# %%
totEmp1['49-3023']
# Out:
# 1177260

# %%
totEmp10 = bls4yr.loc[bls4yr['year']==2010].groupby('occ_code').tot_emp.sum()
totEmp11 = bls4yr.loc[bls4yr['year']==2011].groupby('occ_code').tot_emp.sum()
totEmp = round(((totEmp11 - totEmp10)/totEmp10)*100,2)
totEmp.to_frame()
# Out:
#           tot_emp
# occ_code
# 00-0000      0.93
# 11-0000      2.67
# 11-1011     -2.24
# 11-1021      5.68
# 11-1031     -5.37
# ...           ...
# 53-7073      1.77
# 53-7081     -2.53
# 53-7111      0.00
# 53-7121      5.49
# 53-7199      1.18
#
# [819 rows x 1 columns]

# %%
totEmp[totEmp == 0.38]
# Out:
# occ_code
# 45-0000    0.38
# 49-3023    0.38
# Name: tot_emp, dtype: float64
