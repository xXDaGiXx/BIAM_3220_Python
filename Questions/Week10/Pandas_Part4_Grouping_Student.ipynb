# %% [markdown]
# # `pandas` Part 4: Grouping and Sorting
#
# # Learning Objectives
# ## By the end of this tutorial you will be able to:
# 1. Group data with `groupby()`
# 2. Sort data with `sort_values()`
#
#
# ## Files Needed for this lesson: `winemag-data-130k-v2.csv`
# >- Download this csv from Canvas prior to the lesson
#
# ## The general steps to working with pandas:
# 1. import pandas as pd
# 2. Create or load data into a pandas DataFrame or Series
# 3. Reading data with `pd.read_`
# >- Excel files: `pd.read_excel('fileName.xlsx')`
# >- Csv files: `pd.read_csv('fileName.csv')`
# >- Note: if the file you want to read into your notebook is not in the same folder you can do one of two things:
# >>- Move the file you want to read into the same folder/directory as the notebook
# >>- Type out the full path into the read function
# 4. After steps 1-3 you will want to check out your DataFrame
# >- Use `shape` to see how many records and columns are in your DataFrame
# >- Use `head()` to show the first 5-10 records in your DataFrame

# %% [markdown]
# # Analytics Project Framework Notes
# ## A complete and thorough analytics project will have 3 main areas
# 1. Descriptive Analytics: tells us what has happened or what is happening.
# >- The focus of this lesson is how to do this in python.
# >- Many companies are at this level but not much more than this
# >- Descriptive statistics (mean, median, mode, frequencies)
# >- Graphical analysis (bar charts, pie charts, histograms, box-plots, etc)
# 2. Predictive Analytics: tells us what is likely to happen next
# >- Less companies are at this level but are slowly getting there
# >- Predictive statistics ("machine learning (ML)" using regression, multi-way frequency analysis, etc)
# >- Graphical analysis (scatter plots with regression lines, decision trees, etc)
# 3. Prescriptive Analytics: tells us what to do based on the analysis
# >- Synthesis and Report writing: executive summaries, data-based decision making
# >- No analysis is complete without a written report with at least an executive summary
# >- Communicate results of analysis to both non-technical and technical audiences

# %% [markdown]
# # Descriptive Analytics Using `pandas`

# %% [markdown]
# # Initial set-up steps
# 1. import modules and check working directory
# 2. Read data in
# 3. Check the data

# %%
import os, pandas as pd

# %% [markdown]
# # Step 2 Read Data Into a DataFrame with `read_csv()`
# >- file name: `winemag-data-130k-v2.csv`
# >- Set the index to column 0

# %%
wineReviews = pd.read_csv("winemag-data-130k-v2.csv", index_col = 0)

# %% [markdown]
# ### Check how many rows, columns, and data points are in the `wine_reviews` DataFrame
# >- Use `shape` and indices to define variables
# >- We can store the values for rows and columns in variables if we want to access them later

# %%
rows = wineReviews.shape[0]
columns = wineReviews.shape[1]
totCells = rows * columns

print(f'''The wine dataset has:
        {rows} rows,
        {columns} columns,
        {totCells} total Entries
        ''')
# Out:
# The wine dataset has:
#         129971 rows,
#         13 columns,
#         1689623 total Entries

# %% [markdown]
# ### Check a couple of rows of data

# %%
wineReviews.head(2)
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
# 1      87   15.0              Douro      NaN      NaN     Roger Voss
#
#   taster_twitter_handle                                          title  \
# 0          @kerinokeefe              Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger  Quinta dos Avidagos 2011 Avidagos Red (Douro)
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos

# %% [markdown]
# # Descriptive Analytics with `groupby()`
# >- General syntax: dataFrame.groupby(['fields to group by']).fieldsToanalyze.aggregation

# %% [markdown]
# ### Now, what is/are the question(s) being asked of the data?
# >- All analytics projects start with questions (from you, your boss, some decision maker, etc)

# %% [markdown]
# ###  How many wines have been rated at each point value?

# %%
wineReviews.groupby(['points']).points.count()
# Out:
# points
# 80       397
# 81       692
# 82      1836
# 83      3025
# 84      6480
# 85      9530
# 86     12600
# 87     16933
# 88     17207
# 89     12226
# 90     15410
# 91     11359
# 92      9613
# 93      6489
# 94      3758
# 95      1535
# 96       523
# 97       229
# 98        77
# 99        33
# 100       19
# Name: points, dtype: int64

# %% [markdown]
# ### How much does the least expensive wine for each point rating cost?

# %%
minPrice = wineReviews.groupby(['points']).price.min()

minPrice
# Out:
# points
# 80      5.0
# 81      5.0
# 82      4.0
# 83      4.0
# 84      4.0
# 85      4.0
# 86      4.0
# 87      5.0
# 88      6.0
# 89      7.0
# 90      8.0
# 91      7.0
# 92     11.0
# 93     12.0
# 94     13.0
# 95     20.0
# 96     20.0
# 97     35.0
# 98     50.0
# 99     44.0
# 100    80.0
# Name: price, dtype: float64

# %% [markdown]
# ### Question: How much does the most expensive wine for each point rating cost?

# %%
maxPrice = wineReviews.groupby(['points']).price.max()

maxPrice
# Out:
# points
# 80       69.0
# 81      130.0
# 82      150.0
# 83      225.0
# 84      225.0
# 85      320.0
# 86      170.0
# 87      800.0
# 88     3300.0
# 89      500.0
# 90      510.0
# 91     2013.0
# 92      750.0
# 93      770.0
# 94     1125.0
# 95      973.0
# 96     2500.0
# 97     2000.0
# 98     1900.0
# 99      850.0
# 100    1500.0
# Name: price, dtype: float64

# %% [markdown]
# ### What is the overall maximum price for all wines?

# %%
max(maxPrice)
# Out:
# 3300.0

# %% [markdown]
# ### What is the lowest price for a wine rating of 100?

# %%
minPrice[100]
# Out:
# 80.0

# %% [markdown]
# ### What is the highest price for a wine rating of 80?

# %%
maxPrice[80]
# Out:
# 69.0

# %% [markdown]
# ### What is the maximum rating for each country?

# %%
countryMax = wineReviews.groupby(['country']).points.max()

countryMax
# Out:
# country
# Argentina                  97
# Armenia                    88
# Australia                 100
# Austria                    98
# Bosnia and Herzegovina     88
# Brazil                     89
# Bulgaria                   91
# Canada                     94
# Chile                      95
# China                      89
# Croatia                    91
# Cyprus                     89
# Czech Republic             89
# Egypt                      84
# England                    95
# France                    100
# Georgia                    92
# Germany                    98
# Greece                     93
# Hungary                    97
# India                      93
# Israel                     94
# Italy                     100
# Lebanon                    91
# Luxembourg                 90
# Macedonia                  89
# Mexico                     92
# Moldova                    91
# Morocco                    93
# New Zealand                95
# Peru                       86
# Portugal                  100
# Romania                    92
# Serbia                     89
# Slovakia                   87
# Slovenia                   92
# South Africa               95
# Spain                      98
# Switzerland                90
# Turkey                     92
# US                        100
# Ukraine                    88
# Uruguay                    92
# Name: points, dtype: int64

# %% [markdown]
# ### What is the maximum rating for China?

# %%
countryMax['China']
# Out:
# 89

# %% [markdown]
# ##### Another way to get maximum ratring for China combining `where` and `groupby`

# %%
wineReviews.where(wineReviews['country']=='China').groupby(['country']).points.max()
# Out:
# country
# China    89.0
# Name: points, dtype: float64

# %% [markdown]
# ### What are some summary stats for price for each country?
# >- Using the `agg()` function for specific summary stats
# >>- What is the sample size?
# >>- What is the minimum?
# >>- What is the maximum?
# >>- What is the mean?
# >>- What is the median?
# >>- What is the standard deviation?

# %%
round(wineReviews.groupby(['country']).price.agg(['count','min','max','median','std']))
# Out:
#                         count   min     max  median   std
# country
# Argentina                3756   4.0   230.0    17.0  23.0
# Armenia                     2  14.0    15.0    14.0   1.0
# Australia                2294   5.0   850.0    21.0  49.0
# Austria                  2799   7.0  1100.0    25.0  27.0
# Bosnia and Herzegovina      2  12.0    13.0    12.0   1.0
# Brazil                     47  10.0    60.0    20.0  11.0
# Bulgaria                  141   8.0   100.0    13.0  10.0
# Canada                    254  12.0   120.0    30.0  20.0
# Chile                    4416   5.0   400.0    15.0  22.0
# China                       1  18.0    18.0    18.0   NaN
# Croatia                    71  12.0    65.0    20.0  13.0
# Cyprus                     11  11.0    21.0    16.0   3.0
# Czech Republic             12  15.0    45.0    18.0  12.0
# Egypt                       0   NaN     NaN     NaN   NaN
# England                    69  25.0    95.0    50.0  15.0
# France                  17776   5.0  3300.0    25.0  74.0
# Georgia                    84   9.0    40.0    18.0   8.0
# Germany                  2120   5.0   775.0    26.0  63.0
# Greece                    461   8.0    79.0    19.0  11.0
# Hungary                   145  10.0   764.0    25.0  69.0
# India                       9  10.0    20.0    12.0   4.0
# Israel                    489   8.0   150.0    25.0  19.0
# Italy                   16914   5.0   900.0    28.0  38.0
# Lebanon                    35  13.0    75.0    25.0  18.0
# Luxembourg                  6  16.0    30.0    23.0   5.0
# Macedonia                  12  15.0    20.0    15.0   1.0
# Mexico                     70   8.0   108.0    22.0  18.0
# Moldova                    59   8.0    42.0    13.0  10.0
# Morocco                    28  14.0    40.0    18.0   6.0
# New Zealand              1378   7.0   130.0    20.0  17.0
# Peru                       16  10.0    68.0    14.0  14.0
# Portugal                 4875   5.0  1000.0    16.0  41.0
# Romania                   120   4.0   320.0     9.0  30.0
# Serbia                     12  15.0    42.0    21.0  10.0
# Slovakia                    1  16.0    16.0    16.0   NaN
# Slovenia                   80   7.0    90.0    20.0  14.0
# South Africa             1293   5.0   330.0    19.0  22.0
# Spain                    6573   4.0   770.0    18.0  35.0
# Switzerland                 7  21.0   160.0    38.0  70.0
# Turkey                     90  14.0   120.0    20.0  14.0
# US                      54265   4.0  2013.0    30.0  27.0
# Ukraine                    14   6.0    13.0     9.0   2.0
# Uruguay                   109  10.0   130.0    20.0  18.0

# %%
countryAgg = wineReviews.groupby(['country']).price.describe()

countryAgg
# Out:
#                           count       mean        std   min    25%   50%  \
# country
# Argentina                3756.0  24.510117  23.430122   4.0  12.00  17.0
# Armenia                     2.0  14.500000   0.707107  14.0  14.25  14.5
# Australia                2294.0  35.437663  49.049458   5.0  15.00  21.0
# Austria                  2799.0  30.762772  27.224797   7.0  18.00  25.0
# Bosnia and Herzegovina      2.0  12.500000   0.707107  12.0  12.25  12.5
# Brazil                     47.0  23.765957  11.053649  10.0  15.00  20.0
# Bulgaria                  141.0  14.645390   9.508744   8.0  10.00  13.0
# Canada                    254.0  35.712598  19.658148  12.0  21.00  30.0
# Chile                    4416.0  20.786458  21.929371   5.0  12.00  15.0
# China                       1.0  18.000000        NaN  18.0  18.00  18.0
# Croatia                    71.0  25.450704  12.993173  12.0  16.50  20.0
# Cyprus                     11.0  16.272727   2.831639  11.0  14.50  16.0
# Czech Republic             12.0  24.250000  12.053856  15.0  15.00  18.0
# Egypt                       0.0        NaN        NaN   NaN    NaN   NaN
# England                    69.0  51.681159  14.858641  25.0  43.00  50.0
# France                  17776.0  41.139120  73.769404   5.0  16.00  25.0
# Georgia                    84.0  19.321429   7.642873   9.0  13.00  17.5
# Germany                  2120.0  42.257547  62.860308   5.0  18.00  26.0
# Greece                    461.0  22.364425  10.610780   8.0  15.00  19.0
# Hungary                   145.0  40.648276  69.451075  10.0  19.00  25.0
# India                       9.0  13.333333   3.640055  10.0  12.00  12.0
# Israel                    489.0  31.768916  18.898287   8.0  18.00  25.0
# Italy                   16914.0  39.663770  38.052479   5.0  18.00  28.0
# Lebanon                    35.0  30.685714  18.038800  13.0  19.50  25.0
# Luxembourg                  6.0  23.333333   4.633213  16.0  22.25  23.0
# Macedonia                  12.0  15.583333   1.443376  15.0  15.00  15.0
# Mexico                     70.0  26.785714  17.755091   8.0  15.25  22.0
# Moldova                    59.0  16.745763   9.522375   8.0  10.00  13.0
# Morocco                    28.0  19.500000   5.903546  14.0  16.50  18.0
# New Zealand              1378.0  26.931785  17.101083   7.0  16.00  20.0
# Peru                       16.0  18.062500  13.664888  10.0  14.00  14.5
# Portugal                 4875.0  26.218256  41.175241   5.0  12.00  16.0
# Romania                   120.0  15.241667  30.286863   4.0   7.00   9.0
# Serbia                     12.0  24.500000  10.264679  15.0  17.50  21.0
# Slovakia                    1.0  16.000000        NaN  16.0  16.00  16.0
# Slovenia                   80.0  24.812500  13.982895   7.0  15.00  20.0
# South Africa             1293.0  24.668987  21.843064   5.0  13.00  19.0
# Spain                    6573.0  28.215275  34.662397   4.0  13.00  18.0
# Switzerland                 7.0  85.285714  70.063577  21.0  29.00  38.0
# Turkey                     90.0  24.633333  13.799894  14.0  17.00  20.0
# US                      54265.0  36.573464  27.088857   4.0  20.00  30.0
# Ukraine                    14.0   9.214286   2.190138   6.0   9.00   9.0
# Uruguay                   109.0  26.403670  18.483786  10.0  16.00  20.0
#
#                            75%     max
# country
# Argentina                25.00   230.0
# Armenia                  14.75    15.0
# Australia                38.00   850.0
# Austria                  36.50  1100.0
# Bosnia and Herzegovina   12.75    13.0
# Brazil                   29.00    60.0
# Bulgaria                 16.00   100.0
# Canada                   40.75   120.0
# Chile                    20.00   400.0
# China                    18.00    18.0
# Croatia                  27.50    65.0
# Cyprus                   17.50    21.0
# Czech Republic           28.75    45.0
# Egypt                      NaN     NaN
# England                  60.00    95.0
# France                   43.00  3300.0
# Georgia                  25.00    40.0
# Germany                  42.00   775.0
# Greece                   26.00    79.0
# Hungary                  39.00   764.0
# India                    13.00    20.0
# Israel                   40.00   150.0
# Italy                    50.00   900.0
# Lebanon                  40.00    75.0
# Luxembourg               25.25    30.0
# Macedonia                15.25    20.0
# Mexico                   29.50   108.0
# Moldova                  21.00    42.0
# Morocco                  18.00    40.0
# New Zealand              30.00   130.0
# Peru                     17.00    68.0
# Portugal                 28.00  1000.0
# Romania                  12.00   320.0
# Serbia                   29.50    42.0
# Slovakia                 16.00    16.0
# Slovenia                 30.00    90.0
# South Africa             29.00   330.0
# Spain                    30.00   770.0
# Switzerland             160.00   160.0
# Turkey                   27.75   120.0
# US                       45.00  2013.0
# Ukraine                  10.00    13.0
# Uruguay                  29.00   130.0

# %% [markdown]
# ## What are the descriptive analytics for country and province?
# >- We can group by multiple fields by adding more to our groupby() function

# %%
wineReviews.groupby(['country','province']).points.describe()
# Out:
#                              count       mean       std   min    25%   50%  \
# country   province
# Argentina Mendoza Province  3264.0  86.826593  3.233570  80.0  84.00  87.0
#           Other              536.0  86.001866  2.726470  80.0  84.00  86.0
# Armenia   Armenia              2.0  87.500000  0.707107  87.0  87.25  87.5
# Australia Australia Other    245.0  85.518367  2.194598  80.0  84.00  85.0
#           New South Wales     85.0  87.694118  2.600474  82.0  86.00  88.0
# ...                            ...        ...       ...   ...    ...   ...
# Uruguay   Juanico             12.0  86.333333  3.498918  80.0  83.50  87.0
#           Montevideo          11.0  88.272727  2.493628  83.0  87.00  88.0
#           Progreso            11.0  86.818182  2.182576  82.0  86.50  87.0
#           San Jose             3.0  84.000000  2.645751  82.0  82.50  83.0
#           Uruguay             24.0  86.833333  2.713359  81.0  85.00  87.0
#
#                               75%   max
# country   province
# Argentina Mendoza Province  89.00  97.0
#           Other             88.00  95.0
# Armenia   Armenia           87.75  88.0
# Australia Australia Other   87.00  93.0
#           New South Wales   90.00  94.0
# ...                           ...   ...
# Uruguay   Juanico           89.25  90.0
#           Montevideo        90.50  91.0
#           Progreso          88.00  90.0
#           San Jose          85.00  87.0
#           Uruguay           89.00  91.0
#
# [425 rows x 8 columns]

# %% [markdown]
# ## What are the descriptive price analytics for the US?
# >- Add `get_group()` syntax

# %%
wineReviews.groupby(['country']).get_group('US').price.describe()
# Out:
# count    54265.000000
# mean        36.573464
# std         27.088857
# min          4.000000
# 25%         20.000000
# 50%         30.000000
# 75%         45.000000
# max       2013.000000
# Name: price, dtype: float64

# %% [markdown]
# ## What are the summary wine rating stats for Colorado?
# >- Note that states are coded in this dataset under province

# %%
wineReviews.groupby(['country','province']).get_group(('US','Colorado')).points.describe()
# Out:
# count    68.000000
# mean     86.117647
# std       1.943450
# min      80.000000
# 25%      85.000000
# 50%      86.000000
# 75%      87.000000
# max      91.000000
# Name: points, dtype: float64

# %%
wineReviews.groupby(['province']).get_group('Colorado').points.describe()
# Out:
# count    68.000000
# mean     86.117647
# std       1.943450
# min      80.000000
# 25%      85.000000
# 50%      86.000000
# 75%      87.000000
# max      91.000000
# Name: points, dtype: float64

# %% [markdown]
# # Sorting Results
# >- Add sort_values() syntax
# >- Default is ascending order
# ## What are the summary stats for points for each country?
# >- Sort the results from lowest to highest mean points

# %%
wineReviews.groupby(['country']).points.describe().sort_values(by='mean')
# Out:
#                           count       mean       std   min    25%   50%  \
# country
# Peru                       16.0  83.562500  1.860779  80.0  82.00  84.0
# Egypt                       1.0  84.000000       NaN  84.0  84.00  84.0
# Ukraine                    14.0  84.071429  1.591530  82.0  83.00  84.0
# Brazil                     52.0  84.673077  2.340782  80.0  83.00  85.0
# Mexico                     70.0  85.257143  2.722348  80.0  83.00  85.0
# Romania                   120.0  86.400000  1.716945  82.0  85.00  86.0
# Chile                    4472.0  86.493515  2.692959  80.0  85.00  86.0
# Bosnia and Herzegovina      2.0  86.500000  2.121320  85.0  85.75  86.5
# Argentina                3800.0  86.710263  3.179627  80.0  84.00  87.0
# Uruguay                   109.0  86.752294  2.687957  80.0  85.00  87.0
# Macedonia                  12.0  86.833333  1.749459  84.0  85.75  87.0
# Slovakia                    1.0  87.000000       NaN  87.0  87.00  87.0
# Cyprus                     11.0  87.181818  1.601136  85.0  86.00  87.0
# Moldova                    59.0  87.203390  2.419601  82.0  86.00  88.0
# Croatia                    73.0  87.219178  2.399344  81.0  86.00  88.0
# Czech Republic             12.0  87.250000  1.712255  84.0  86.50  88.0
# Greece                    466.0  87.283262  2.185293  82.0  86.00  87.0
# Spain                    6645.0  87.288337  3.066284  80.0  85.00  87.0
# Serbia                     12.0  87.500000  1.314257  86.0  86.00  87.5
# Armenia                     2.0  87.500000  0.707107  87.0  87.25  87.5
# Lebanon                    35.0  87.685714  2.784109  82.0  86.50  88.0
# Georgia                    86.0  87.686047  2.087845  82.0  87.00  88.0
# Bulgaria                  141.0  87.936170  2.077817  80.0  87.00  89.0
# South Africa             1401.0  88.056388  2.435826  82.0  86.00  88.0
# Slovenia                   87.0  88.068966  1.730661  82.0  87.00  88.0
# Turkey                     90.0  88.088889  1.975379  84.0  87.00  88.0
# Portugal                 5691.0  88.250220  2.996122  80.0  86.00  88.0
# New Zealand              1419.0  88.303030  2.435008  80.0  87.00  88.0
# Israel                    505.0  88.471287  2.478412  80.0  87.00  89.0
# Italy                   19540.0  88.562231  2.649756  80.0  87.00  88.0
# US                      54504.0  88.563720  3.114840  80.0  86.00  88.0
# Switzerland                 7.0  88.571429  2.507133  83.0  89.00  89.0
# Morocco                    28.0  88.571429  1.687175  85.0  88.00  88.5
# Australia                2329.0  88.580507  2.989900  80.0  87.00  89.0
# Luxembourg                  6.0  88.666667  0.816497  88.0  88.00  88.5
# France                  22093.0  88.845109  3.044423  80.0  87.00  89.0
# China                       1.0  89.000000       NaN  89.0  89.00  89.0
# Hungary                   146.0  89.191781  2.686659  81.0  88.00  89.0
# Canada                    257.0  89.369650  2.384752  82.0  88.00  90.0
# Germany                  2165.0  89.851732  2.469351  81.0  88.00  90.0
# Austria                  3345.0  90.101345  2.499799  82.0  88.00  90.0
# India                       9.0  90.222222  1.715938  87.0  90.00  90.0
# England                    74.0  91.581081  1.843216  89.0  90.00  91.0
#
#                           75%    max
# country
# Peru                    85.00   86.0
# Egypt                   84.00   84.0
# Ukraine                 84.75   88.0
# Brazil                  86.00   89.0
# Mexico                  87.00   92.0
# Romania                 87.25   92.0
# Chile                   88.00   95.0
# Bosnia and Herzegovina  87.25   88.0
# Argentina               89.00   97.0
# Uruguay                 88.00   92.0
# Macedonia               88.00   89.0
# Slovakia                87.00   87.0
# Cyprus                  88.50   89.0
# Moldova                 89.00   91.0
# Croatia                 89.00   91.0
# Czech Republic          88.25   89.0
# Greece                  89.00   93.0
# Spain                   89.00   98.0
# Serbia                  89.00   89.0
# Armenia                 87.75   88.0
# Lebanon                 90.00   91.0
# Georgia                 89.00   92.0
# Bulgaria                89.00   91.0
# South Africa            90.00   95.0
# Slovenia                89.00   92.0
# Turkey                  90.00   92.0
# Portugal                90.00  100.0
# New Zealand             90.00   95.0
# Israel                  90.00   94.0
# Italy                   90.00  100.0
# US                      91.00  100.0
# Switzerland             90.00   90.0
# Morocco                 89.25   93.0
# Australia               91.00  100.0
# Luxembourg              89.00   90.0
# France                  91.00  100.0
# China                   89.00   89.0
# Hungary                 90.00   97.0
# Canada                  91.00   94.0
# Germany                 91.00   98.0
# Austria                 92.00   98.0
# India                   91.00   93.0
# England                 93.00   95.0

# %% [markdown]
# ### To sort in descending order...
# >- Use ascending = False

# %%
wineReviews.groupby(['country']).points.describe().sort_values(by='mean',ascending = False)
# Out:
#                           count       mean       std   min    25%   50%  \
# country
# England                    74.0  91.581081  1.843216  89.0  90.00  91.0
# India                       9.0  90.222222  1.715938  87.0  90.00  90.0
# Austria                  3345.0  90.101345  2.499799  82.0  88.00  90.0
# Germany                  2165.0  89.851732  2.469351  81.0  88.00  90.0
# Canada                    257.0  89.369650  2.384752  82.0  88.00  90.0
# Hungary                   146.0  89.191781  2.686659  81.0  88.00  89.0
# China                       1.0  89.000000       NaN  89.0  89.00  89.0
# France                  22093.0  88.845109  3.044423  80.0  87.00  89.0
# Luxembourg                  6.0  88.666667  0.816497  88.0  88.00  88.5
# Australia                2329.0  88.580507  2.989900  80.0  87.00  89.0
# Switzerland                 7.0  88.571429  2.507133  83.0  89.00  89.0
# Morocco                    28.0  88.571429  1.687175  85.0  88.00  88.5
# US                      54504.0  88.563720  3.114840  80.0  86.00  88.0
# Italy                   19540.0  88.562231  2.649756  80.0  87.00  88.0
# Israel                    505.0  88.471287  2.478412  80.0  87.00  89.0
# New Zealand              1419.0  88.303030  2.435008  80.0  87.00  88.0
# Portugal                 5691.0  88.250220  2.996122  80.0  86.00  88.0
# Turkey                     90.0  88.088889  1.975379  84.0  87.00  88.0
# Slovenia                   87.0  88.068966  1.730661  82.0  87.00  88.0
# South Africa             1401.0  88.056388  2.435826  82.0  86.00  88.0
# Bulgaria                  141.0  87.936170  2.077817  80.0  87.00  89.0
# Georgia                    86.0  87.686047  2.087845  82.0  87.00  88.0
# Lebanon                    35.0  87.685714  2.784109  82.0  86.50  88.0
# Armenia                     2.0  87.500000  0.707107  87.0  87.25  87.5
# Serbia                     12.0  87.500000  1.314257  86.0  86.00  87.5
# Spain                    6645.0  87.288337  3.066284  80.0  85.00  87.0
# Greece                    466.0  87.283262  2.185293  82.0  86.00  87.0
# Czech Republic             12.0  87.250000  1.712255  84.0  86.50  88.0
# Croatia                    73.0  87.219178  2.399344  81.0  86.00  88.0
# Moldova                    59.0  87.203390  2.419601  82.0  86.00  88.0
# Cyprus                     11.0  87.181818  1.601136  85.0  86.00  87.0
# Slovakia                    1.0  87.000000       NaN  87.0  87.00  87.0
# Macedonia                  12.0  86.833333  1.749459  84.0  85.75  87.0
# Uruguay                   109.0  86.752294  2.687957  80.0  85.00  87.0
# Argentina                3800.0  86.710263  3.179627  80.0  84.00  87.0
# Bosnia and Herzegovina      2.0  86.500000  2.121320  85.0  85.75  86.5
# Chile                    4472.0  86.493515  2.692959  80.0  85.00  86.0
# Romania                   120.0  86.400000  1.716945  82.0  85.00  86.0
# Mexico                     70.0  85.257143  2.722348  80.0  83.00  85.0
# Brazil                     52.0  84.673077  2.340782  80.0  83.00  85.0
# Ukraine                    14.0  84.071429  1.591530  82.0  83.00  84.0
# Egypt                       1.0  84.000000       NaN  84.0  84.00  84.0
# Peru                       16.0  83.562500  1.860779  80.0  82.00  84.0
#
#                           75%    max
# country
# England                 93.00   95.0
# India                   91.00   93.0
# Austria                 92.00   98.0
# Germany                 91.00   98.0
# Canada                  91.00   94.0
# Hungary                 90.00   97.0
# China                   89.00   89.0
# France                  91.00  100.0
# Luxembourg              89.00   90.0
# Australia               91.00  100.0
# Switzerland             90.00   90.0
# Morocco                 89.25   93.0
# US                      91.00  100.0
# Italy                   90.00  100.0
# Israel                  90.00   94.0
# New Zealand             90.00   95.0
# Portugal                90.00  100.0
# Turkey                  90.00   92.0
# Slovenia                89.00   92.0
# South Africa            90.00   95.0
# Bulgaria                89.00   91.0
# Georgia                 89.00   92.0
# Lebanon                 90.00   91.0
# Armenia                 87.75   88.0
# Serbia                  89.00   89.0
# Spain                   89.00   98.0
# Greece                  89.00   93.0
# Czech Republic          88.25   89.0
# Croatia                 89.00   91.0
# Moldova                 89.00   91.0
# Cyprus                  88.50   89.0
# Slovakia                87.00   87.0
# Macedonia               88.00   89.0
# Uruguay                 88.00   92.0
# Argentina               89.00   97.0
# Bosnia and Herzegovina  87.25   88.0
# Chile                   88.00   95.0
# Romania                 87.25   92.0
# Mexico                  87.00   92.0
# Brazil                  86.00   89.0
# Ukraine                 84.75   88.0
# Egypt                   84.00   84.0
# Peru                    85.00   86.0
